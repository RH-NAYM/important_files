# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/train_sample
# Out:
# /content/drive/MyDrive/train_sample

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-128-gb96f35c Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.6/78.2 GB disk)

# %%
# !unzip '/content/drive/MyDrive/train sample/sample_dataset.zip'

# %%
# !unzip '/content/drive/MyDrive/train_sample/Archive.zip'
# Out:
# Archive:  /content/drive/MyDrive/train_sample/Archive.zip
#   inflating: data.yaml
#   inflating: __MACOSX/._data.yaml
#    creating: test/
#   inflating: __MACOSX/._test
#   inflating: test/.DS_Store
#   inflating: __MACOSX/test/._.DS_Store
#    creating: test/images/
#   inflating: __MACOSX/test/._images
#    creating: test/labels/
#   inflating: __MACOSX/test/._labels
#   inflating: test/images/IMG_20230320_165829_jpg.rf.9fd54542f2201d66cf1e99eb23cac001.jpg
#   inflating: __MACOSX/test/images/._IMG_20230320_165829_jpg.rf.9fd54542f2201d66cf1e99eb23cac001.jpg
#   inflating: test/images/IMG_20230402_124516_jpg.rf.f3df13de0b719f69289ee4a62d67fb0d.jpg
#   inflating: __MACOSX/test/images/._IMG_20230402_124516_jpg.rf.f3df13de0b719f69289ee4a62d67fb0d.jpg
#   inflating: test/images/IMG_20230320_165744_jpg.rf.96c78602805102377bdd515dc0acbf99.jpg
#   inflating: __MACOSX/test/images/._IMG_20230320_165744_jpg.rf.96c78602805102377bdd515dc0acbf99.jpg
# ...

# %%
# Train New Model
# %cd /content/drive/MyDrive/train_sample/yolov5
# !python train.py --img 416 --batch 16 --epochs 200 --data data.yaml --weights yolov5x6.pt --cache

# %%
# Retrain Old Model
# %cd /content/drive/MyDrive/train_sample/yolov5
# !python train.py --epochs 1000 --data data.yaml --weights /content/drive/MyDrive/train_sample/best.pt --cache
# Out:
# /content/drive/MyDrive/train_sample/yolov5
# train: weights=/content/drive/MyDrive/train_sample/best.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=500, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 13 (delta 8), reused 10 (delta 8), pack-reused 0
# Unpacking objects: 100% (13/13), 14.22 KiB | 14.00 KiB/s, done.
# Command 'git fetch origin' timed out after 5 seconds
# ...

# %% [markdown]
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)

# %%
# Retrain Old Model
# %cd /content/drive/MyDrive/train_sample/yolov5
# !python train.py --epochs 1000 --data data.yaml --weights runs/train/exp/weights/best.pt --cache
# Out:
# /content/drive/MyDrive/train_sample/yolov5
# train: weights=runs/train/exp/weights/best.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=500, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 5 commits. Use 'git pull' or 'git clone https://github.com/ultralytics/yolov5' to update.
# YOLOv5 🚀 v7.0-128-gb96f35c Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Retrain Old Model
# %cd /content/drive/MyDrive/train_sample/yolov5
# !python train.py --epochs 1000 --data data.yaml --weights runs/train/exp2/weights/best.pt --cache

# %%
# Retrain Old Model
# %cd /content/drive/MyDrive/train_sample/yolov5
# !python train.py --epochs 1000 --data data.yaml --weights runs/train/exp3/weights/best.pt --cache

# %%
# %cd /content/drive/MyDrive/train sample/yolov5
# %reload_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# %cd /content/drive/MyDrive/train_sample/yolov5/
# !python export.py --weights runs/train/exp2/weights/best.pt --include tflite
# Out:
# /content/drive/MyDrive/train_sample/yolov5
# export: data=data/coco128.yaml, weights=['runs/train/exp2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-128-gb96f35c Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 416 layers, 140115052 parameters, 0 gradients
#
# PyTorch: starting from runs/train/exp2/weights/best.pt with output shape (1, 25500, 21) (1070.9 MB)
# 2023-04-11 17:20:25.592219: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)

# %%
# Test the Data
# %cd /content/drive/MyDrive/train sample/yolov5
# !python detect.py --weights runs/train/exp20/weights/best.pt --source /content/drive/MyDrive/train sample/yolov5/train
